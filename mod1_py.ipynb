# %%
a=10
PI = 3.141592
def randin(x):
  return 3*x+6
class Calculator:
  def setData(self, first, second):
    self.first = first #가독성 확보를 위해 이름을 동일하게 유지함
    self.second = second
  def add(self): #메서드
    self.result = self.first + self.second
  def div(self):
    self.result = self.first / self.second
  def sub(self):
    self.resulf = self.first - self.second
